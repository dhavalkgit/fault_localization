# %%
import pandas as pd
import csv

# %%
for i in range(1,10):
    df=pd.read_csv('/home/dhaval/Sem_3/fault_localization-main/coverage/schedule/statementResultV'+str(i)+'.csv')
    df=df.drop_duplicates()
    df.to_csv('statementResultV'+str(i)+'.csv',index=0)
